# %% [markdown]
# ## Prepare Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from data_util import *

# %%
import time

# %%
no_epochs=20
val_split=0.15
sequence_length = 16  # sequence length

# %% [markdown]
# #### Tranining Data set

# %%
train_df = read_data(get_files(r'.*Case[1-6]_CutFre200.xls'),cut_precent=0.1) # case 1 -6 for traning
train_df.head()
# Out:
#      distance  acceleration  displacement       force
# 0  214.666667      3.933282      0.066135  149.348220
# 1  214.750000      3.615658      0.066152  151.348000
# 2  214.833333      2.675704      0.066173  157.732013
# 3  214.916667      1.334371      0.066197  166.934591
# 4  215.000000      0.114687      0.066221  175.241854

# %%
# Selecting the relevant features
train_features = train_df[['acceleration', 'displacement']]
train_target = train_df['force']

X_train, y_train = create_sequences(train_features, train_target, sequence_length)

# %% [markdown]
# #### Testing Data set

# %%
test_df = read_data(get_files(r'.*Case[7-8]_CutFre200.xls'),cut_precent=0.1) # case 7 to 8 for testing
test_features = test_df[['acceleration', 'displacement']]
test_target = test_df['force']

X_test, y_test = create_sequences(test_features, test_target, sequence_length)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN,Conv1D, Dense,LSTM,Bidirectional,Input,GRU,Flatten,Dropout,Attention
from tensorflow.keras import regularizers
from tensorflow import keras
from keras_self_attention import SeqSelfAttention
# Out:
# 2024-05-04 22:54:20.304812: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
rnn_model = Sequential([
    SimpleRNN(32, input_shape=(sequence_length, 2), return_sequences=True),
    SimpleRNN(32, return_sequences=False),
    Dense(1)
])
rnn_model.compile(optimizer='adam', loss='mean_squared_error')
rnn_model.summary()
# Out:
# /Users/lahaale/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 16, 32)         │         1,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,233 (12.63 KB)
#  Trainable params: 3,233 (12.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
rnn_history = rnn_model.fit(X_train, y_train, epochs=no_epochs, validation_split=val_split, verbose=1)
# Out:
# Epoch 1/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 34s 5ms/step - loss: 21748.0859 - val_loss: 1672.9142
# Epoch 2/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - loss: 1941.5719 - val_loss: 382.9857
# Epoch 3/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - loss: 426.6066 - val_loss: 319.4961
# Epoch 4/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - loss: 352.3761 - val_loss: 335.0783
# Epoch 5/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - loss: 344.4629 - val_loss: 310.8647
# Epoch 6/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - loss: 346.4852 - val_loss: 329.9954
# Epoch 7/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - loss: 330.0571 - val_loss: 309.3328
# Epoch 8/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 329.4508 - val_loss: 308.1904
# Epoch 9/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - loss: 327.6787 - val_loss: 345.9917
# Epoch 10/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 323.9879 - val_loss: 300.3336
# Epoch 11/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - loss: 322.7310 - val_loss: 302.5810
# Epoch 12/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - loss: 321.1620 - val_loss: 363.5752
# Epoch 13/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - loss: 318.9902 - val_loss: 291.6230
# Epoch 14/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - loss: 317.1336 - val_loss: 318.7318
# Epoch 15/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - loss: 317.4439 - val_loss: 309.9207
# Epoch 16/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - loss: 316.7495 - val_loss: 381.2232
# Epoch 17/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - loss: 315.9055 - val_loss: 341.4468
# Epoch 18/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - loss: 311.8563 - val_loss: 345.6282
# Epoch 19/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - loss: 314.6979 - val_loss: 363.6122
# Epoch 20/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - loss: 310.7806 - val_loss: 355.1684

# %%
rnn_model.save("models/rnn_model.keras")
pd.DataFrame(data = rnn_history.history).to_csv("history/rnn_hist.csv")
time.sleep(60*5)

# %%
gru_model = Sequential([
    GRU(32, input_shape=(sequence_length, 2), return_sequences=True),
    GRU(32, return_sequences=False),
    # SeqSelfAttention(attention_activation='sigmoid'),
    Dense(1)
])
gru_model.compile(optimizer='adam', loss='mean_squared_error')
gru_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 16, 32)         │         3,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 32)             │         6,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,825 (38.38 KB)
#  Trainable params: 9,825 (38.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
gru_history = gru_model.fit(X_train, y_train, epochs=no_epochs, validation_split=val_split, verbose=1)
# Out:
# Epoch 1/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 59s 9ms/step - loss: 21559.9980 - val_loss: 1687.3153
# Epoch 2/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 56s 9ms/step - loss: 1823.7605 - val_loss: 378.1704
# Epoch 3/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 55s 9ms/step - loss: 396.2605 - val_loss: 317.6278
# Epoch 4/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 57s 9ms/step - loss: 337.6110 - val_loss: 347.8230
# Epoch 5/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 58s 10ms/step - loss: 323.4044 - val_loss: 304.4071
# Epoch 6/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 58s 10ms/step - loss: 316.2240 - val_loss: 323.8380
# Epoch 7/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 71s 12ms/step - loss: 310.2259 - val_loss: 338.0880
# Epoch 8/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 54s 9ms/step - loss: 306.4242 - val_loss: 320.5571
# Epoch 9/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 59s 10ms/step - loss: 302.3604 - val_loss: 377.8668
# Epoch 10/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 66s 11ms/step - loss: 296.7703 - val_loss: 298.9795
# Epoch 11/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 59s 10ms/step - loss: 294.0981 - val_loss: 336.1596
# Epoch 12/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 57s 9ms/step - loss: 292.9959 - val_loss: 332.8998
# Epoch 13/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 64s 11ms/step - loss: 287.1256 - val_loss: 358.3408
# Epoch 14/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 62s 10ms/step - loss: 285.2145 - val_loss: 315.7090
# Epoch 15/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 58s 9ms/step - loss: 282.2648 - val_loss: 301.9932
# Epoch 16/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 56s 9ms/step - loss: 279.4343 - val_loss: 337.5266
# Epoch 17/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 58s 10ms/step - loss: 279.0235 - val_loss: 379.6209
# Epoch 18/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 57s 9ms/step - loss: 276.8700 - val_loss: 322.6370
# Epoch 19/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 61s 10ms/step - loss: 272.5658 - val_loss: 321.2629
# Epoch 20/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 57s 9ms/step - loss: 271.2725 - val_loss: 328.1116

# %%
gru_model.save("models/gru_model.keras")
pd.DataFrame(data = gru_history.history).to_csv("history/gru_hist.csv")
time.sleep(60*5)

# %%
gru_att_model = Sequential([
    GRU(32, input_shape=(sequence_length, 2), return_sequences=True),
    SeqSelfAttention(attention_activation='sigmoid'),
    GRU(32, return_sequences=False),
    Dense(1)
])
gru_att_model.compile(optimizer='adam', loss='mean_squared_error')
gru_att_model.summary()
gru_att_history = gru_att_model.fit(X_train, y_train, epochs=no_epochs, validation_split=val_split, verbose=1)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_2 (GRU)                     │ (None, 16, 32)         │         3,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ seq_self_attention              │ (None, 16, 32)         │         2,113 │
# │ (SeqSelfAttention)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 32)             │         6,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,938 (46.63 KB)
#  Trainable params: 11,938 (46.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 72s 11ms/step - loss: 21589.1641 - val_loss: 1685.4349
# Epoch 2/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 69s 11ms/step - loss: 2575.7258 - val_loss: 378.4512
# Epoch 3/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 73s 12ms/step - loss: 493.9664 - val_loss: 429.4328
# Epoch 4/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 69s 11ms/step - loss: 365.0705 - val_loss: 354.5557
# Epoch 5/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 69s 11ms/step - loss: 343.5020 - val_loss: 324.1710
# Epoch 6/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 72s 12ms/step - loss: 329.5618 - val_loss: 348.0563
# Epoch 7/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 81s 13ms/step - loss: 323.9196 - val_loss: 358.5901
# Epoch 8/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 81s 13ms/step - loss: 318.8996 - val_loss: 329.6664
# Epoch 9/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 78s 13ms/step - loss: 312.3008 - val_loss: 313.4560
# Epoch 10/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 85s 14ms/step - loss: 307.9547 - val_loss: 327.5563
# Epoch 11/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 80s 13ms/step - loss: 302.6534 - val_loss: 342.8345
# Epoch 12/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 62s 10ms/step - loss: 298.3304 - val_loss: 367.4772
# Epoch 13/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 69s 11ms/step - loss: 293.8026 - val_loss: 352.7385
# Epoch 14/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 65s 11ms/step - loss: 292.0013 - val_loss: 323.1310
# Epoch 15/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 62s 10ms/step - loss: 288.5726 - val_loss: 347.8124
# Epoch 16/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 63s 10ms/step - loss: 286.2108 - val_loss: 299.7714
# Epoch 17/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 68s 11ms/step - loss: 282.5367 - val_loss: 354.5479
# Epoch 18/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 65s 11ms/step - loss: 280.6022 - val_loss: 340.8513
# Epoch 19/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 68s 11ms/step - loss: 279.2255 - val_loss: 356.8152
# Epoch 20/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 72s 12ms/step - loss: 276.7675 - val_loss: 333.7888

# %%
gru_att_model.save("models/gru_att_model.keras")
pd.DataFrame(data = gru_att_history.history).to_csv("history/gru_att_hist.csv")
time.sleep(60*5)

# %%
def cnn_gru_model(steps=sequence_length,feature_size=2, output_size=1,req=True):
    model = Sequential()
    model.add(Input(shape=(steps,feature_size)))
    model.add(Conv1D(64, 1, activation='relu'))
    model.add(GRU(32, return_sequences=True))
    model.add(GRU(32,return_sequences=False))
    model.add(Dense(output_size))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
cnn_gru_model = cnn_gru_model()
cnn_gru_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 16, 64)         │           192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_4 (GRU)                     │ (None, 16, 32)         │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_5 (GRU)                     │ (None, 32)             │         6,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,969 (62.38 KB)
#  Trainable params: 15,969 (62.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cnn_gru_history = cnn_gru_model.fit(X_train, y_train,  epochs=no_epochs, validation_split=val_split, verbose=1)
# Out:
# Epoch 1/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 62s 10ms/step - loss: 22105.6777 - val_loss: 1705.0715
# Epoch 2/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 57s 9ms/step - loss: 2669.6741 - val_loss: 422.7908
# Epoch 3/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 58s 10ms/step - loss: 473.8978 - val_loss: 340.7292
# Epoch 4/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 59s 10ms/step - loss: 339.1050 - val_loss: 331.5402
# Epoch 5/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 59s 10ms/step - loss: 322.4565 - val_loss: 315.8075
# Epoch 6/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 60s 10ms/step - loss: 311.7248 - val_loss: 318.5100
# Epoch 7/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 60s 10ms/step - loss: 305.6891 - val_loss: 324.6646
# Epoch 8/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 59s 10ms/step - loss: 296.4164 - val_loss: 309.3367
# Epoch 9/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 59s 10ms/step - loss: 291.0681 - val_loss: 313.5443
# Epoch 10/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 60s 10ms/step - loss: 280.2770 - val_loss: 369.1819
# Epoch 11/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 60s 10ms/step - loss: 268.0244 - val_loss: 309.4232
# Epoch 12/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 62s 10ms/step - loss: 250.6379 - val_loss: 343.0425
# Epoch 13/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 61s 10ms/step - loss: 230.7367 - val_loss: 231.2317
# Epoch 14/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 59s 10ms/step - loss: 212.3215 - val_loss: 255.0561
# Epoch 15/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 60s 10ms/step - loss: 202.8436 - val_loss: 261.8222
# Epoch 16/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 62s 10ms/step - loss: 193.6191 - val_loss: 213.5375
# Epoch 17/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 59s 10ms/step - loss: 187.4404 - val_loss: 228.4825
# Epoch 18/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 61s 10ms/step - loss: 181.1919 - val_loss: 251.4203
# Epoch 19/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 57s 9ms/step - loss: 180.4226 - val_loss: 221.3201
# Epoch 20/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 61s 10ms/step - loss: 172.2172 - val_loss: 282.1389

# %%
cnn_gru_model.save("models/cnn_gru_model.keras")
pd.DataFrame(data = cnn_gru_history.history).to_csv("history/cnn_gru_hist.csv")
# time.sleep(60*5)

# %%
# reg = regularizers.l1_l2(0.01)
def lstm_model(steps=sequence_length,feature_size=2, output_size=1,req=True):
    model = Sequential()
    # model.add(Input(shape=(steps,feature_size)))
    # model.add(Conv1D(64, 1, activation='relu'))
    model.add(LSTM(32,input_shape=(sequence_length, 2), return_sequences=True))
    model.add(LSTM(32,return_sequences=False))
    model.add(Dense(output_size))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
lstm_model = lstm_model()
lstm_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 16, 32)         │         4,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,833 (50.13 KB)
#  Trainable params: 12,833 (50.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
lstm_history = lstm_model.fit(X_train, y_train,  epochs=no_epochs, validation_split=val_split, verbose=1)
# Out:
# Epoch 1/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 47s 7ms/step - loss: 21601.9375 - val_loss: 1685.9100
# Epoch 2/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - loss: 1943.5222 - val_loss: 393.7440
# Epoch 3/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 44s 7ms/step - loss: 408.4612 - val_loss: 329.7414
# Epoch 4/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 43s 7ms/step - loss: 344.7044 - val_loss: 356.0401
# Epoch 5/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 49s 8ms/step - loss: 331.1992 - val_loss: 377.1063
# Epoch 6/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 46s 8ms/step - loss: 329.0914 - val_loss: 345.3056
# Epoch 7/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 49s 8ms/step - loss: 317.3506 - val_loss: 306.9983
# Epoch 8/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 48s 8ms/step - loss: 315.6928 - val_loss: 369.5067
# Epoch 9/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 44s 7ms/step - loss: 309.7414 - val_loss: 355.0116
# Epoch 10/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 41s 7ms/step - loss: 306.3953 - val_loss: 326.4863
# Epoch 11/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - loss: 303.0959 - val_loss: 324.1631
# Epoch 12/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - loss: 298.9932 - val_loss: 317.3321
# Epoch 13/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 41s 7ms/step - loss: 296.8402 - val_loss: 307.0662
# Epoch 14/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 43s 7ms/step - loss: 292.6866 - val_loss: 324.4708
# Epoch 15/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 40s 7ms/step - loss: 289.8759 - val_loss: 311.7936
# Epoch 16/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 46s 8ms/step - loss: 289.2613 - val_loss: 354.1882
# Epoch 17/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 39s 6ms/step - loss: 288.3059 - val_loss: 331.0608
# Epoch 18/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 45s 7ms/step - loss: 285.3063 - val_loss: 324.2602
# Epoch 19/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 43s 7ms/step - loss: 281.7019 - val_loss: 308.3478
# Epoch 20/20
# 6067/6067 ━━━━━━━━━━━━━━━━━━━━ 45s 7ms/step - loss: 278.0648 - val_loss: 334.8015

# %%
lstm_model.save("models/lstm_model.keras")
pd.DataFrame(data = lstm_history.history).to_csv("history/lstm_hist.csv")
time.sleep(60*5)

# %%
# def dnn_model(steps=sequence_length,feature_size=2, output_size=1,req=True):
#     model = Sequential()
#     model.add(Input(shape=(steps,feature_size)))
#     model.add(Flatten())
#     model.add(Dense(32))
#     model.add(Dense(32))
#     model.add(Dense(1))
#     model.compile(optimizer='adam', loss='mean_squared_error')
#     return model

# dnn_model = dnn_model()
# dnn_model.summary()

# %%
# dnn_history = dnn_model.fit(X_train, y_train,  epochs=no_epochs, validation_split=val_split, verbose=1)

# %%
# from sklearn.svm import SVR
# svr_rbf = SVR(kernel="rbf", C=100, gamma=0.1, epsilon=0.1)
# svr_rbf.fit(train_df[['acceleration','displacement']], train_df.force)

# %%
# x = X_train.reshape(X_train.shape[0],-1)

# %%
# gru_model.save("models/gru_model.keras")
# lstm_model.save("models/lstm_model.keras")
# gru_att_model.save("models/gru_att_model.keras")

# %%
# def dnn_model2(steps=sequence_length,feature_size=2, output_size=1,req=True):
#     model = Sequential()
#     model.add(Dense(32,input_dim=feature_size))
#     model.add(Dense(32))
#     model.add(Dense(1))
#     model.compile(optimizer='adam', loss='mean_squared_error')
#     return model

# dnn_model1 = dnn_model2()
# dnn_model1.summary()

# %%
# dnn_history1 = dnn_model1.fit(train_features, train_target,  epochs=no_epochs, validation_split=val_split, verbose=1)

# %%
# rnn_model.load_weights("models/rnn_model.keras")
# new_model = tf.keras.models.load_model('my_model.keras')

# %%
# rnn_model = tf.keras.models.load_model("models/rnn_model.keras")
# dnn_model = tf.keras.models.load_model("models/dnn_model.keras")
# lstm_model = tf.keras.models.load_model("models/lstm_model.keras")

# %%
rnn_pred = rnn_model.predict(X_test)
gru_pred = gru_model.predict(X_test)
lstm_pred = lstm_model.predict(X_test)
cnn_gru_pred = cnn_gru_model.predict(X_test)
# dnn_pred1 = dnn_model1.predict(test_features[sequence_length:])
# Out:
# 1036/1036 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 1036/1036 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 1036/1036 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 1036/1036 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
lstm_pred.shape
# Out:
# (33141, 1)

# %%
gru_pred.shape
# Out:
# (33141, 1)

# %%
plt.scatter(y_test,lstm_pred);
plt.xlabel("Force")
plt.ylabel("Predicted Force");

# %%
plt.scatter(y_test,cnn_gru_pred);
plt.xlabel("Force")
plt.ylabel("Predicted Force");

# %%
def plot_slot(start=500,end=601,filename="image"):
    epoch_count = range(start,end)

    plt.plot(epoch_count, y_test[start:end], 'ro-',linewidth=2.0,markevery=20)
    # plt.plot(epoch_count, dnn_pred1[start:end], 'm--',linewidth=2.0)
    # plt.plot(epoch_count, dnn_pred[start:end], 'b--',linewidth=2.0)
    plt.plot(epoch_count, gru_pred[start:end], 'm^--',linewidth=2.0,markevery=20)
    plt.plot(epoch_count, cnn_gru_pred[start:end], 'bX--',linewidth=2.0,markevery=20)
    plt.plot(epoch_count, rnn_pred[start:end], 'yh--',linewidth=2.0,markevery=20)
    plt.plot(epoch_count, lstm_pred[start:end], 'gd--',linewidth=2.0,markevery=20)
    plt.legend(['Force',"GRU","CNN-GRU", "RNN","LSTM"])
    plt.xlabel('Time Slots')
    plt.ylabel('Force')
    #plt.title(title)
    plt.grid(True)
    plt.savefig("images/"+filename+".pdf",dpi=200,format = "pdf")
    # plt.show()

# %%
plt.rcParams.update({'figure.autolayout': True})

# %%
SMALL_SIZE = 14
MEDIUM_SIZE = 14
BIGGER_SIZE = 14

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rcParams["figure.figsize"] = (8,6)
plt.style.use("classic")

# %%
plot_slot(19600,20000,"ex20_Fre200_Case7_8")

# %%
plot_slot(8200,8600,"ex11_Fre200_Case7_8")

# %%
df_val = pd.DataFrame(data = {
              # "DNN-TM":dnn_history.history["val_loss"],
              "RNN":rnn_history.history["val_loss"],
              "GRU":gru_history.history["loss"],
              "CNN_GRU":cnn_gru_history.history["loss"],
              "LSTM":rnn_history.history["val_loss"]
                                         })
df_val.head()
df_val.to_csv("history/val_loss.csv")

# %%
df_val = pd.DataFrame(data = {
              # "DNN-TM":dnn_history.history["loss"],
              "RNN":rnn_history.history["loss"],
              "GRU":gru_history.history["loss"],
              "CNN_GRU":cnn_gru_history.history["loss"],
              "LSTM":rnn_history.history["loss"]
                                         })
df_val.head()
df_val.to_csv("history/loss.csv")

# %%
def plot_models_performance(gru=None, rnn=None, lstm=None,cnn_gru=None, title="Proctive Model"):
    lstm_accuracy = lstm.history['val_loss'][2:no_epochs]
    rnn_accuracy = rnn.history['val_loss'][2:no_epochs]
    gru_accuracy = gru.history['val_loss'][2:no_epochs]
    gru_att_acc = cnn_gru.history['val_loss'][2:no_epochs]


    # Create count of the number of epochs
    epoch_count = range(1, len(lstm_accuracy) + 1)

    # Visualize loss history
    plt.plot(epoch_count, gru_accuracy, 'gd--',linewidth=2.0)
    plt.plot(epoch_count, gru_att_acc, 'ro--',linewidth=2.0)
    plt.plot(epoch_count, rnn_accuracy, 'y*--',linewidth=2.0)
    plt.plot(epoch_count, lstm_accuracy, 'c^--',linewidth=2.0)
   
    plt.legend(['GRU','CNN-GRU', "RNN", "LSTM"])
    plt.xlabel('epochs')
    plt.ylabel('Validation Loss')
    plt.grid(True)
    plt.savefig("images/"+"val_loss.pdf",dpi=200,format = "pdf")

plot_models_performance(gru_history,rnn_history,lstm_history,cnn_gru_history,title="Adaptive Validation Loss")

# %%
def plot_models_performance(gru=None, rnn=None, lstm=None, gru_att=None,title="Proctive Model"):
    lstm_accuracy = lstm.history['loss'][2:no_epochs]
    rnn_accuracy = rnn.history['loss'][2:no_epochs]
    gru_accuracy = gru.history['loss'][2:no_epochs]
    gru_att_acc = gru_att.history['val_loss'][2:no_epochs]


    # Create count of the number of epochs
    epoch_count = range(1, len(lstm_accuracy) + 1)

    # Visualize loss history
    plt.plot(epoch_count, gru_accuracy, 'gd--',linewidth=2.0)
    plt.plot(epoch_count, gru_att_acc, 'ro--',linewidth=2.0)
    plt.plot(epoch_count, rnn_accuracy, 'y*--',linewidth=2.0)
    plt.plot(epoch_count, lstm_accuracy, 'c^--',linewidth=2.0)
    # plt.plot(epoch_count, deep_nn_accuracy, 'b--')
    plt.legend(['GRU','CNN-GRU', "RNN", "LSTM"])
    plt.xlabel('epochs')
    plt.ylabel('Loss')
    # plt.title(title)
    plt.grid(True)
    plt.savefig("images/"+"loss.pdf",dpi=200,format = "pdf")

plot_models_performance(gru_history,rnn_history,lstm_history,cnn_gru_history,title="Loss")

# %%
test_df = read_data(get_files(r'.*Case[7]_CutFre20.xls'),cut_precent=0.1) # case 7 to 8 for testing
test_features = test_df[['acceleration', 'displacement']]
test_target = test_df['force']

X_test, y_test = create_sequences(test_features, test_target, sequence_length)

# %%
from sklearn.metrics import mean_squared_error

# %%
def plot_error(finame="bar"):
    rnn_pred = rnn_model.predict(X_test)
    gru_pred = gru_model.predict(X_test)
    lstm_pred = lstm_model.predict(X_test)
    gru_att_pred = cnn_gru_model.predict(X_test)
    # dnn_pred1 = dnn_model1.predict(test_features[sequence_length:])

    rnn_mse = mean_squared_error(rnn_pred, y_test)
    # dnn_tm_mse = mean_squared_error(dnn_pred, y_test)
    # dnn_mse = mean_squared_error(dnn_pred1, y_test)
    gru_mse = mean_squared_error(gru_pred, y_test)
    gru_att_mse = mean_squared_error(gru_att_pred, y_test)
    lstm_mse = mean_squared_error(lstm_pred, y_test)

    fig, ax = plt.subplots()
    fruits = ['RNN','GRU','CNN-GRU', 'LSTM']
    counts = [rnn_mse, gru_mse, gru_att_mse, lstm_mse]
    bar_labels = ['RNN','GRU','CNN-GRU', 'LSTM']
    bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

    ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

    ax.set_ylabel('Mean Sqaure Error')
    # ax.set_title('Fruit supply by kind and color')
    # ax.legend(title='Models')
    plt.grid(True)
    # plt.show()
    plt.savefig("images/"+finame+".pdf",dpi=200,format = "pdf")
    return counts

# %%
trained_Fre200_test_Fre200 = plot_error("trained_Fre200_test_Fre200_case7_8")
# Out:
# 2187/2187 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 2187/2187 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step
# 2187/2187 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 2187/2187 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step

# %%
test_df = read_data(get_files(r'.*Case[2-3]_CutFre20.xls'),cut_precent=0.1) # case 7 to 8 for testing
test_features = test_df[['acceleration', 'displacement']]
test_target = test_df['force']

X_test, y_test = create_sequences(test_features, test_target, sequence_length)

# %%
trained_Fre200_test_on_Fre20_case2_3 = plot_error("trained_Fre200_test_on_Fre20_case2_3")
# Out:
# 2303/2303 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 2303/2303 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 2303/2303 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 2303/2303 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step

# %%
rnn_pred = rnn_model.predict(X_test)
gru_pred = gru_model.predict(X_test)
lstm_pred = lstm_model.predict(X_test)
cnn_gru_pred = cnn_gru_model.predict(X_test)
# Out:
# 2303/2303 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 2303/2303 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step
# 2303/2303 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 2303/2303 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step

# %%
plot_slot(1500,2000,"ex2_trained_Fre200_test_on_Fre20_case2_3")

# %%
test_df = read_data(get_files(r'.*Case[3-4]_CutFre50.xls'),cut_precent=0.1) # case 7 to 8 for testing
test_features = test_df[['acceleration', 'displacement']]
test_target = test_df['force']

X_test, y_test = create_sequences(test_features, test_target, sequence_length)

# %%
trained_Fre200_test_on_Fre50_case3_4 = plot_error("trained_Fre200_test_on_Fre50_case3_4")
# Out:
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step

# %%
rnn_pred = rnn_model.predict(X_test)
gru_pred = gru_model.predict(X_test)
lstm_pred = lstm_model.predict(X_test)
cnn_gru_pred = cnn_gru_model.predict(X_test)
# Out:
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step

# %%
plot_slot(10500,11000,"ex4_trained_Fre200_test_on_Fre50_case3_4")

# %%
test_df = read_data(get_files(r'.*Case[4-5]_CutFre100.xls'),cut_precent=0.1) # case 7 to 8 for testing
test_features = test_df[['acceleration', 'displacement']]
test_target = test_df['force']

X_test, y_test = create_sequences(test_features, test_target, sequence_length)

# %%
trained_Fre200_test_on_Fre100_case4_5 = plot_error("trained_Fre200_test_on_Fre100_case4_5")
# Out:
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step

# %%
rnn_pred = rnn_model.predict(X_test)
gru_pred = gru_model.predict(X_test)
lstm_pred = lstm_model.predict(X_test)
cnn_gru_pred = cnn_gru_model.predict(X_test)
# Out:
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step

# %%
plot_slot(3200,3500,"ex7_trained_Fre200_test_on_Fre100_case4_5")

# %%
test_df = read_data(get_files(r'.*Case[5-6]_CutFre150.xls'),cut_precent=0.1) # case 7 to 8 for testing
test_features = test_df[['acceleration', 'displacement']]
test_target = test_df['force']

X_test, y_test = create_sequences(test_features, test_target, sequence_length)
trained_Fre200_test_on_Fre150_case5_6 = plot_error("trained_Fre200_test_on_Fre150_case5_6")
# Out:
# 2418/2418 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 2418/2418 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 2418/2418 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 2418/2418 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step

# %%
rnn_pred = rnn_model.predict(X_test)
gru_pred = gru_model.predict(X_test)
lstm_pred = lstm_model.predict(X_test)
cnn_gru_pred = cnn_gru_model.predict(X_test)
# Out:
# 2418/2418 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 2418/2418 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 2418/2418 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 2418/2418 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step

# %%
plot_slot(6600,6800,"ex10_trained_Fre200_test_on_Fre150_case5_6")

# %%
error_df = pd.DataFrame(data={
    "F 20\n C 2,3":trained_Fre200_test_on_Fre20_case2_3,
    "F 50\n C 3,4":trained_Fre200_test_on_Fre50_case3_4,
    "F 100 \n C 4,5":trained_Fre200_test_on_Fre100_case4_5,
    "F 150\n C 5,6":trained_Fre200_test_on_Fre150_case5_6,
    "F 200\n C 7,8":trained_Fre200_test_Fre200
                             })
error_df.head()
# Out:
#    F 20\n C 2,3  F 50\n C 3,4  F 100 \n C 4,5  F 150\n C 5,6  F 200\n C 7,8
# 0    539.434235    499.010756      493.859100     559.464317     358.288058
# 1    659.408135    597.709847      520.701199     555.435228     339.064056
# 2    347.128676    283.147145      285.271022     361.076684     268.663339
# 3    562.831710    512.854467      481.933424     553.088099     349.591767

# %%
error_df.index = ['RNN','GRU','CNN-GRU', 'LSTM']
error_df.head()
# Out:
#          F 20\n C 2,3  F 50\n C 3,4  F 100 \n C 4,5  F 150\n C 5,6  \
# RNN        539.434235    499.010756      493.859100     559.464317
# GRU        659.408135    597.709847      520.701199     555.435228
# CNN-GRU    347.128676    283.147145      285.271022     361.076684
# LSTM       562.831710    512.854467      481.933424     553.088099
#
#          F 200\n C 7,8
# RNN         358.288058
# GRU         339.064056
# CNN-GRU     268.663339
# LSTM        349.591767

# %%
error_df.transpose().plot(kind="bar")
plt.xlabel("Frequencies (F) and Cases (C)",fontsize=18) 
plt.ylabel("Mean Sqaure Error",fontsize=18) 
plt.xticks(rotation=45,fontsize=18) 
plt.yticks(fontsize=18) 
plt.grid(True)
plt.savefig("images/mode_freq200.pdf",dpi=200,format = "pdf")

# %%
error_df.to_csv("history/model200_err.csv")
