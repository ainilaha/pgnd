# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### load function from `data_tutil.py`.

# %%
from data_util import get_files, read_data

# %% [markdown]
# ### list data with frequency 20 hz

# %%
get_files(r'.*Fre20.xls')
# Out:
# ['V300_Case1_CutFre20.xls',
#  'V300_Case6_CutFre20.xls',
#  'V350_Case7_CutFre20.xls',
#  'V350_Case6_CutFre20.xls',
#  'V350_Case1_CutFre20.xls',
#  'V300_Case7_CutFre20.xls',
#  'V380_Case6_CutFre20.xls',
#  'V380_Case1_CutFre20.xls',
#  'V380_Case7_CutFre20.xls',
#  'V350_Case8_CutFre20.xls',
#  'V380_Case5_CutFre20.xls',
#  'V380_Case2_CutFre20.xls',
#  'V300_Case8_CutFre20.xls',
#  'V380_Case3_CutFre20.xls',
#  'V380_Case4_CutFre20.xls',
#  'V350_Case3_CutFre20.xls',
#  'V350_Case4_CutFre20.xls',
#  'V300_Case2_CutFre20.xls',
#  'V300_Case5_CutFre20.xls',
#  'V300_Case4_CutFre20.xls',
#  'V300_Case3_CutFre20.xls',
#  'V350_Case5_CutFre20.xls',
#  'V350_Case2_CutFre20.xls',
#  'V380_Case8_CutFre20.xls']

# %%
fre20_df = get_files(r'.*Case[1-6]_CutFre20.xls') # case 1 to 6

# %%
fre20_df = read_data(fre20_files[0:2],cut_precent=0.1)
fre20_df.head()
# Out:
#         distance  acceleration  displacement       force
# 1373  195.138889      8.378788      0.077768  200.364359
# 1374  195.244444      8.530177      0.077660  198.599368
# 1375  195.350000      8.596483      0.077561  197.318811
# 1376  195.455556      8.579577      0.077470  196.510644
# 1377  195.561111      8.482142      0.077388  196.158104

# %%
fre20_df.force.plot();

# %%
fre150_df = read_data(get_files(r'.*Fre150.xls'),cut_precent=0.1)
fre150_df.head()
# Out:
#         distance  acceleration  displacement       force
# 1640  214.638889      1.791968      0.073851  164.328706
# 1641  214.736111     -1.448836      0.073950  186.448162
# 1642  214.833333     -3.870473      0.074049  202.802415
# 1643  214.930556     -4.777039      0.074144  208.455952
# 1644  215.027778     -3.846701      0.074235  201.122794

# %%
fre20_df.force.plot();

# %%
fre20_df.iloc[0:15000].force.plot();

# %%
import seaborn as sns
sns.set_theme(style="white")

# %%
g = sns.jointplot(data=fre20_df, x="acceleration", y="displacement",kind='kde', fill=True)
g.plot_joint(sns.kdeplot, color="r", zorder=0, levels=6);

# %%
g = sns.jointplot(data=fre20_df, x="acceleration", y="force",kind='kde', fill=True)
g.plot_joint(sns.kdeplot, color="r", zorder=0, levels=6);

# %%
g = sns.jointplot(data=fre20_df, x="displacement", y="force",kind='kde', fill=True)
g.plot_joint(sns.kdeplot, color="r", zorder=0, levels=6);

# %%
g = sns.jointplot(data=fre20_df, x="acceleration", y="force",kind='kde', fill=True)
g.plot_joint(sns.kdeplot, color="r", zorder=0, levels=6);
